# %% [markdown]
# # USC Well Data Dataset Quick Start
#
# Version 0.95
#
# USC Well Data is an Academic Hub dataset hosted by the OSIsoft Cloud Service (OCS, https://www.osisoft.com/solutions/cloud/vision/), a cloud-native real-time data infrastructure used to perform enterprise-wide analytics using tools and languages of the user's choice.
#
#
# **Raw operational data has specific characteristics making it difficult to deal with directly**, among them:
#
# * variable data collection frequencies
# * bad values (system error codes)
# * data gaps
#
#
# **But data science projects using operational data needs to be:**
#
# * **Time-aligned** to deal with the characteritics above in consistent way according to the data type (e.g. interpolation for float values, repeat last good value for categorical data, etc)
# * **Context aware** so that the data can be understandable, across as many real-world assets that you need it for
# * **Shaped and filtered** to ensure you have the data you need, in the form you need it
#
# **The OCS solutions for application-ready data are Data Views:**
#
# ![](https://academichub.blob.core.windows.net/images/piworld-dse-dataview-p2.png)
#
# **Each Academic Hub datasets comes endowed with a set of asset-centric data views.**
#
# The goal of Academic Hub Python library is to provide a very generic and consistent way to access:
#
# * the list of existing datasets
# * for a given dataset:
#   * the list of its assets
#   * the OCS namespace where the dataset is hosted
# * for a given asset, the list of data views it belongs to

# %% [markdown]
# ## Install Academic Hub Python library
#
# <div class="alert alert-block alert-warning">
# <b>NOTE: you may have to restart the kernel if this is the first time those modules are installed</b>
# </div>

# %%
# %pip install ocs-academic-hub
# %pip install plotly
# Out:
# Requirement already satisfied: ocs-academic-hub in c:\jupyterlab\resources\jlab_server\lib\site-packages (0.99.6)
# Requirement already satisfied: gql in c:\jupyterlab\resources\jlab_server\lib\site-packages (from ocs-academic-hub) (2.0.0)
# Requirement already satisfied: backoff in c:\jupyterlab\resources\jlab_server\lib\site-packages (from ocs-academic-hub) (1.11.1)
# Requirement already satisfied: pandas>=0.24.2 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from ocs-academic-hub) (1.3.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from ocs-academic-hub) (2.8.2)
# Requirement already satisfied: ocs-sample-library-hub==0.1.19 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from ocs-academic-hub) (0.1.19)
# Requirement already satisfied: numpy in c:\jupyterlab\resources\jlab_server\lib\site-packages (from ocs-academic-hub) (1.21.2)
# Requirement already satisfied: typeguard>=2.4.1 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from ocs-academic-hub) (2.13.0)
# Requirement already satisfied: requests>=2.25.1 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from ocs-sample-library-hub==0.1.19->ocs-academic-hub) (2.26.0)
# Requirement already satisfied: pytz>=2017.3 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from pandas>=0.24.2->ocs-academic-hub) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from python-dateutil>=2.8.0->ocs-academic-hub) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from requests>=2.25.1->ocs-sample-library-hub==0.1.19->ocs-academic-hub) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from requests>=2.25.1->ocs-sample-library-hub==0.1.19->ocs-academic-hub) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from requests>=2.25.1->ocs-sample-library-hub==0.1.19->ocs-academic-hub) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from requests>=2.25.1->ocs-sample-library-hub==0.1.19->ocs-academic-hub) (1.26.7)
# Requirement already satisfied: promise<3,>=2.3 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from gql->ocs-academic-hub) (2.3)
# Requirement already satisfied: graphql-core<3,>=2.3.2 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from gql->ocs-academic-hub) (2.3.2)
# Requirement already satisfied: rx<2,>=1.6 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from graphql-core<3,>=2.3.2->gql->ocs-academic-hub) (1.6.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: plotly in c:\jupyterlab\resources\jlab_server\lib\site-packages (5.3.1)
# Requirement already satisfied: six in c:\jupyterlab\resources\jlab_server\lib\site-packages (from plotly) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: tenacity>=6.2.0 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from plotly) (8.0.1)

# %% [markdown]
# ## [Optional] Use the `pip uninstall` only in case of library issues

# %%
# It's sometimes necessary to uninstall previous versions, uncomment and run the following line. 
# Then restart kernel and reinstall with previous cell
#!pip uninstall -y ocs-academic-hub ocs-sample-library-preview

# %% [markdown]
# ## Import HubClient, necessary to connect and interact with OCS

# %%
from ocs_academic_hub import HubClient
import datetime

# %% [markdown]
# ## Running the following cell initiates the login sequence
#
# **Warning:** a new brower tab will open offering the choice of identifying with Microsoft or Google. You should always pick Google:
# <img src="https://academichub.blob.core.windows.net/images/ocs-login-page-google.png" alt="Login screen" width="600"/>
#
# Return to this web page when done

# %%
hub = HubClient()
# Out:
# Step 1: Get OAuth endpoint configuration...
# Step 2: Set up server to process authorization response...
# Step 3: Authorize the user...
# Step 4: Set server to handle one request...
# 127.0.0.1 - - [19/Oct/2021 19:00:51] "GET /callback.html?code=44F82827CD06D69EA927C2D38780AE77FCCD63D45F9F3B4B90266B004CD8EAAB&scope=openid%20ocsapi&session_state=KbuiHre5KtKexXke6CC7yGKAJR3pBnRF__av_fNKsMk.DFBC8C26581C541F1576F881093F1058 HTTP/1.1" 200 -
# Step 5: Get a token using the authorization code...
# Step 6: Access token read ok
# Complete!
# @ Hub data file: hub_datasets.json

# %% [markdown]
# ## Refresh datasets information
#
# Over time existing datasets are updated and new ones are added. The cell below makes sure you have the latest version of the production datasets.
#
# Note: after execution of this method, a file named `hub_datasets.json` will be created in the same directory as this notebook. The data in this file supersedes the one built-in with the `ocs_academic_hub` module. To get back to the built-in datasets information, move/rename/delete `hub_datasets.json`.

# %%
hub.refresh_datasets(experimental=True)
# Out:
# @ Hub data file: hub_datasets.json
# @ Current dataset: Brewery

# %% [markdown]
# ## Get list of published hub datasets

# %%
hub.datasets()
# Out:
# ['Brewery',
#  'Campus_Energy',
#  'Classroom_Data',
#  'MIT',
#  'Pilot_Plant',
#  'USC_Well_Data',
#  'Wind_Farms']

# %% [markdown]
# ## Display current active dataset
#
# The default dataset is Brewery. Only one dataset can be active at a time.

# %%
hub.current_dataset()
# Out:
# 'Brewery'

# %% [markdown]
# ## Set USC Well Data as the current dataset

# %%
hub.set_dataset("USC_Well_Data")

# %% [markdown]
# ## Verify that MIT dataset is active

# %%
hub.current_dataset()
# Out:
# 'USC_Well_Data'

# %% [markdown]
# ## Get list of assets with Data Views
#
# Returned into the form of a pandas dataframe, with column `Asset_Id` and `Description`. Each asset has a unique `Asset_Id` as its identity.

# %%
wells = hub.assets()
wells
# Out:
#    Asset_Id                    Description
# 0     20197      WADE FEDERAL  5300 21-30H
# 1     20275     KLINE FEDERAL  5300 11-18H
# 2     20314     LEWIS FEDERAL  5300 31-31H
# 3     20407          CHALMERS  5300 31-19H
# 4     20863     FOLEY FEDERAL  5301 43-12H
# ..      ...                            ...
# 67    29334   KLINE FEDERAL  5300 11-18 2B
# 68    30188    LEWIS FEDERAL 5300 11-31 3B
# 69    30189    LEWIS FEDERAL 5300 11-31 2B
# 70    30789  KLINE FEDERAL  5300 31-18 15T
# 71    36047   LEWIS FEDERAL 5300 11-31 4BR
#
# [72 rows x 2 columns]

# %% [markdown]
# ## List of all Single Asset Data Views
#
# Each asset is assigned a single-asset default data view. The default data view contains all the sensor data for the given asset, each sensor having its own column when requesting a table of interpolated data.

# %%
hub.asset_dataviews(filter="")
# Out:
# ['usc.welldata_20197',
#  'usc.welldata_20275',
#  'usc.welldata_20314',
#  'usc.welldata_20407',
#  'usc.welldata_20863',
#  'usc.welldata_20864',
#  'usc.welldata_21266',
#  'usc.welldata_21796',
#  'usc.welldata_22099',
#  'usc.welldata_22220',
#  'usc.welldata_22221',
#  'usc.welldata_22247',
#  'usc.welldata_22249',
#  'usc.welldata_22731',
#  'usc.welldata_22740',
#  'usc.welldata_23230',
#  'usc.welldata_23359',
#  'usc.welldata_23360',
#  'usc.welldata_23361',
#  'usc.welldata_23362',
#  'usc.welldata_23363',
#  'usc.welldata_23364',
#  'usc.welldata_23365',
#  'usc.welldata_23366',
#  'usc.welldata_23367',
#  'usc.welldata_23368',
#  'usc.welldata_23369',
#  'usc.welldata_23370',
#  'usc.welldata_23371',
#  'usc.welldata_23372',
#  'usc.welldata_25156',
#  'usc.welldata_25157',
#  'usc.welldata_25158',
#  'usc.welldata_25159',
#  'usc.welldata_25160',
#  'usc.welldata_25571',
#  'usc.welldata_28190',
#  'usc.welldata_28194',
#  'usc.welldata_28303',
#  'usc.welldata_28342',
#  'usc.welldata_28394',
#  'usc.welldata_28425',
#  'usc.welldata_28554',
#  'usc.welldata_28557',
#  'usc.welldata_28599',
#  'usc.welldata_28600',
#  'usc.welldata_28601',
#  'usc.welldata_28633',
#  'usc.welldata_28634',
#  'usc.welldata_28636',
#  'usc.welldata_28637',
#  'usc.welldata_28648',
#  'usc.welldata_28649',
#  'usc.welldata_28651',
#  'usc.welldata_28652',
#  'usc.welldata_28654',
#  'usc.welldata_28655',
#  'usc.welldata_28744',
#  'usc.welldata_28754',
#  'usc.welldata_28755',
#  'usc.welldata_28756',
#  'usc.welldata_28976',
#  'usc.welldata_28978',
#  'usc.welldata_29242',
#  'usc.welldata_29244',
#  'usc.welldata_29316',
#  'usc.welldata_29317',
#  'usc.welldata_29334',
#  'usc.welldata_30188',
#  'usc.welldata_30189',
#  'usc.welldata_30789',
#  'usc.welldata_36047']

# %% [markdown]
# ## Get the OCS namespace associated to the dataset
#
# Each data set belongs to a namespace within the Academic Hub OCS account. Since dataset may move over time, the function below always return the active namespace for the given dataset.

# %%
dataset = hub.current_dataset()
namespace_id = hub.namespace_of(dataset)
namespace_id
# Out:
# 'hub_lab_data_01'

# %% [markdown]
# ## Data View Structure
#
# For a given well, get the list of streams (time-series) associated to the well.
#
# NOTE: static metadata is not returned within a Data View but through a different method shown later.

# %%
asset_id = "20197"
dataview_id = f"usc.welldata_{asset_id}"
print("Data View ID:", dataview_id)
hub.dataview_definition(namespace_id, dataview_id)
# Out:
# Data View ID: usc.welldata_20197
#   Asset_Id Column_Name Stream_Type Stream_UOM          OCS_Stream_Name
# 1    20197    BBLS_Oil     Integer               BAKKEN_20197.BBLS_Oil
# 3    20197  BBLS_Water     Integer             BAKKEN_20197.BBLS_Water
# 0    20197        Days     Integer                   BAKKEN_20197.Days
# 4    20197    MCF_Prod     Integer               BAKKEN_20197.MCF_Prod
# 5    20197    MCF_Sold     Integer               BAKKEN_20197.MCF_Sold
# 2    20197        Runs     Integer                   BAKKEN_20197.Runs

# %% [markdown]
# ## Getting data from a Data View
#
# Data Views support two different data retrieval modes: stored and interpolated.
#
#
# <div class="alert alert-block alert-warning">
# <b>Note:</b> since USC well dataset has only one entry per month, interpolated data view is not supported (and useless since maximum interpolation period is about a 24 hours)
# </div>

# %% [markdown]
# ### Stored Data View
#
# Some applications require the raw stored sensor data instead of interpolated values. The parameters required are:
# * Start date
# * End date
#
# All stored values between those two dates, for all sensor in the data view, are returned with one value per row. Regardless of the data view definition, stored retrieval of a data view return a dataframe with the same narrow format of 4 columms:
# * Timestamp
# * Asset_Id
# * Field (column name)
# * Value
#
# The method for stored retrieval is `hub.dataview_stored_pd`

# %%
# Obtain a Pandas dataframe with data spanning the whole current time range of the dataset,
# at 5 minutes interpolated interval starting on 2021-05-10 up to now

now = datetime.datetime.now().isoformat()

df_stored = hub.dataview_stored_pd(namespace_id, dataview_id, "2000-01-01", now)
# Save a copy of the data frame as a CSV file for analysis/inspection with other tools (e.g. Excel)
df_stored.to_csv(f"usc_well_{asset_id}_stored.csv")
# Display preview result data frame
df_stored
# Out:
#   ==> Finished 'dataview_stored_pd' in             0.4856 secs [ 1.27K rows/sec ]
#                     Timestamp  Asset_Id     Field  Value
# 0   2011-07-01 07:00:00+00:00     20197      Days      5
# 1   2011-08-01 07:00:00+00:00     20197      Days     16
# 2   2011-09-01 07:00:00+00:00     20197      Days     30
# 3   2011-10-01 07:00:00+00:00     20197      Days     26
# 4   2011-11-01 07:00:00+00:00     20197      Days     27
# ..                        ...       ...       ...    ...
# 613 2019-09-01 07:00:00+00:00     20197  MCF_Sold      0
# 614 2019-10-01 07:00:00+00:00     20197  MCF_Sold      0
# 615 2019-11-01 07:00:00+00:00     20197  MCF_Sold      0
# 616 2019-12-01 08:00:00+00:00     20197  MCF_Sold      0
# 617 2020-01-01 08:00:00+00:00     20197  MCF_Sold      0
#
# [618 rows x 4 columns]

# %%
df_well = df_stored.pivot_table(values='Value', index='Timestamp', columns='Field')
df_well
# Out:
# Field                      BBLS_Oil  BBLS_Water  Days  MCF_Prod  MCF_Sold  \
# Timestamp
# 2011-07-01 07:00:00+00:00       588        2917     5      3110         0
# 2011-08-01 07:00:00+00:00     14726       20957    16     15699         0
# 2011-09-01 07:00:00+00:00     19852       13968    30     21162         0
# 2011-10-01 07:00:00+00:00     10733        7841    26     11442         0
# 2011-11-01 07:00:00+00:00      9522        6395    27     10151         0
# ...                             ...         ...   ...       ...       ...
# 2019-09-01 07:00:00+00:00      1047        1824    30      1147         0
# 2019-10-01 07:00:00+00:00      1141        1728    31      1218         0
# 2019-11-01 07:00:00+00:00      1089        1634    30      1140         0
# 2019-12-01 08:00:00+00:00      1059        1762    31      1122         0
# 2020-01-01 08:00:00+00:00       591         981    15       624         0
#
# Field                       Runs
# Timestamp
# 2011-07-01 07:00:00+00:00    443
# 2011-08-01 07:00:00+00:00  14497
# 2011-09-01 07:00:00+00:00  19893
# 2011-10-01 07:00:00+00:00  10508
# 2011-11-01 07:00:00+00:00   9384
# ...                          ...
# 2019-09-01 07:00:00+00:00    905
# 2019-10-01 07:00:00+00:00   1200
# 2019-11-01 07:00:00+00:00   1236
# 2019-12-01 08:00:00+00:00    904
# 2020-01-01 08:00:00+00:00    595
#
# [103 rows x 6 columns]

# %% [markdown]
# ## Static well data
#
# Many data fields for well data are static, i.e. with no time component. In Hub datasets, this kind of data is referred to as metadata.
#
# Metadata can obtained in two manners: per asset or all assets.
#
# ### Single asset metatada
#
# Here for well # 20197

# %%
well_20197 = hub.asset_metadata(asset='20197')
well_20197
# Out:
# {'API_No': '33-053-03413-00-00',
#  'CountyName': 'MCKENZIE',
#  'CurrentOperator': 'OASIS PETROLEUM NORTH AMERICA LLC',
#  'CurrentWellName': 'WADE FEDERAL  5300 21-30H',
#  'FieldName': 'BAKER',
#  'File_No': 20197.0,
#  'Footages': '2220 FNL  230 FWL',
#  'Latitude': 48.04714687,
#  'LeaseName': 'WADE FEDERAL',
#  'Longitude': -103.60310009999999,
#  'OilWaterGasCums': '276747|354478|321672',
#  'OriginalOperator': 'OASIS PETROLEUM NORTH AMERICA LLC',
#  'OriginalWellName': 'WADE  5300 21-30H',
#  'Perfs': '11009-20481',
#  'Pool': 'BAKKEN',
#  'ProducedPools': 'BAKKEN',
#  'QQ': 'LOT 2',
#  'Range': '100 W',
#  'Section': 30.0,
#  'SpudDate': '4/5/11',
#  'TD': 20481.0,
#  'Township': '153 N',
#  'Vent/Flare': 761.0,
#  'WellStatus': 'A',
#  'WellStatusDate': '8/15/18',
#  'WellType': 'OG',
#  'Wellbore': 'HORIZONTAL',
#  'Asset_Id': '20197'}

# %% [markdown]
# ### For all wells

# %%
wells_meta = hub.all_assets_metadata()
wells_meta
# Out:
#                 API_No CountyName                    CurrentOperator  \
# 0   33-053-03413-00-00   MCKENZIE  OASIS PETROLEUM NORTH AMERICA LLC
# 1   33-053-03426-00-00   MCKENZIE  OASIS PETROLEUM NORTH AMERICA LLC
# 2   33-053-03433-00-00   MCKENZIE  OASIS PETROLEUM NORTH AMERICA LLC
# 3   33-053-03472-00-00   MCKENZIE  OASIS PETROLEUM NORTH AMERICA LLC
# 4   33-053-03608-00-00   MCKENZIE  OASIS PETROLEUM NORTH AMERICA LLC
# ..                 ...        ...                                ...
# 67  33-053-06243-00-00   MCKENZIE  OASIS PETROLEUM NORTH AMERICA LLC
# 68  33-053-06548-00-00   MCKENZIE  OASIS PETROLEUM NORTH AMERICA LLC
# 69  33-053-06549-00-00   MCKENZIE  OASIS PETROLEUM NORTH AMERICA LLC
# 70  33-053-06755-00-00   MCKENZIE  OASIS PETROLEUM NORTH AMERICA LLC
# 71  33-053-08946-00-00   MCKENZIE  OASIS PETROLEUM NORTH AMERICA LLC
#
#                   CurrentWellName FieldName  File_No           Footages  \
# 0       WADE FEDERAL  5300 21-30H     BAKER  20197.0  2220 FNL  230 FWL
# 1      KLINE FEDERAL  5300 11-18H     BAKER  20275.0   990 FNL  305 FWL
# 2      LEWIS FEDERAL  5300 31-31H     BAKER  20314.0  1435 FSL  300 FWL
# 3           CHALMERS  5300 31-19H     BAKER  20407.0  1535 FSL  375 FWL
# 4      FOLEY FEDERAL  5301 43-12H     BAKER  20863.0  250 FSL  1827 FEL
# ..                            ...       ...      ...                ...
# 67   KLINE FEDERAL  5300 11-18 2B     BAKER  29334.0   960 FNL  318 FWL
# 68    LEWIS FEDERAL 5300 11-31 3B     BAKER  30188.0  1083 FNL  262 FWL
# 69    LEWIS FEDERAL 5300 11-31 2B     BAKER  30189.0  1050 FNL  265 FWL
# 70  KLINE FEDERAL  5300 31-18 15T     BAKER  30789.0  2556 FSL  238 FWL
# 71   LEWIS FEDERAL 5300 11-31 4BR     BAKER  36047.0  1149 FNL  257 FWL
#
#      Latitude      LeaseName   Longitude  ... Section SpudDate       TD  \
# 0   48.047147   WADE FEDERAL -103.603100  ...    30.0   4/5/11  20481.0
# 1   48.079151  KLINE FEDERAL -103.602722  ...    18.0   5/7/11  20650.0
# 2   48.028313  LEWIS FEDERAL -103.602885  ...    31.0  5/28/11  20680.0
# 3   48.057438       CHALMERS -103.602355  ...    19.0   9/1/11  20300.0
# 4   48.082690  FOLEY FEDERAL -103.611486  ...    12.0  7/27/11  20440.0
# ..        ...            ...         ...  ...     ...      ...      ...
# 67  48.079234  KLINE FEDERAL -103.602670  ...    18.0  2/25/15  20450.0
# 68  48.035835  LEWIS FEDERAL -103.603111  ...    31.0   1/3/19  20860.0
# 69  48.035926  LEWIS FEDERAL -103.603100  ...    31.0  1/25/19  20870.0
# 70  48.074633  KLINE FEDERAL -103.602937  ...    18.0   3/6/15  20542.0
# 71  48.035654  LEWIS FEDERAL -103.603130  ...    31.0  2/18/19  20780.0
#
#    Township Vent/Flare WellStatus WellStatusDate WellType    Wellbore Asset_Id
# 0     153 N      761.0          A        8/15/18       OG  HORIZONTAL    20197
# 1     153 N       15.0          A        7/23/11       OG  HORIZONTAL    20275
# 2     153 N        4.0          A        8/22/11       OG  HORIZONTAL    20314
# 3     153 N       41.0          A       11/26/11       OG  HORIZONTAL    20407
# 4     153 N     1073.0          A       11/15/11       OG  HORIZONTAL    20863
# ..      ...        ...        ...            ...      ...         ...      ...
# 67    153 N       86.0          A        9/20/15       OG  HORIZONTAL    29334
# 68    153 N     5069.0          A         8/4/19       OG  HORIZONTAL    30188
# 69    153 N     4346.0          A         8/2/19       OG  HORIZONTAL    30189
# 70    153 N       81.0          A        9/24/15       OG  HORIZONTAL    30789
# 71    153 N     5299.0          A        8/11/19       OG  HORIZONTAL    36047
#
# [72 rows x 28 columns]

# %% [markdown]
# ## Plot for stored data
#
# The cell below shows how to plot stored data using the [Plotly](https://plotly.com/python/plotly-express/) library. The scatter plot (with optional line below) if a good graph since it displays a marker for timestamp with a value.

# %%
# Change the size of the output cell to avoid vertical scrollbar
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 44em; }</style>"))

import plotly.express as px
import plotly.io as pio

pio.renderers.default = 'colab'
fig = px.scatter(
    df_stored,
    x=df_stored["Timestamp"],
    y=df_stored["Value"],
    color=df_stored["Field"],
    range_x=["2011-07-01", "2020-02-01"],
    title=f"Data plot for Well #<b>{asset_id}</b>",
).update_traces(mode="lines+markers")
fig.show()
# Out:
# <style>div.output_scroll { height: 44em; }</style>
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="14b8294d-02ac-4aba-aeb8-1e86842fe6a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14b8294d-02ac-4aba-aeb8-1e86842fe6a9")) {                    Plotly.newPlot(                        "14b8294d-02ac-4aba-aeb8-1e86842fe6a9",                        [{"hovertemplate":"Field=Days<br>Timestamp=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Days","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines+markers","name":"Days","orientation":"v","showlegend":true,"type":"scatter","x":["2011-07-01T07:00:00+00:00","2011-08-01T07:00:00+00:00","2011-09-01T07:00:00+00:00","2011-10-01T07:00:00+00:00","2011-11-01T07:00:00+00:00","2011-12-01T08:00:00+00:00","2012-01-01T08:00:00+00:00","2012-02-01T08:00:00+00:00","2012-03-01T08:00:00+00:00","2012-04-01T07:00:00+00:00","2012-05-01T07:00:00+00:00","2012-06-01T07:00:00+00:00","2012-07-01T07:00:00+00:00","2012-08-01T07:00:00+00:00","2012-09-01T07:00:00+00:00","2012-10-01T07:00:00+00:00","2012-11-01T07:00:00+00:00","2012-12-01T08:00:00+00:00","2013-01-01T08:00:00+00:00","2013-02-01T08:00:00+00:00","2013-03-01T08:00:00+00:00","2013-04-01T07:00:00+00:00","2013-05-01T07:00:00+00:00","2013-06-01T07:00:00+00:00","2013-07-01T07:00:00+00:00","2013-08-01T07:00:00+00:00","2013-09-01T07:00:00+00:00","2013-10-01T07:00:00+00:00","2013-11-01T07:00:00+00:00","2013-12-01T08:00:00+00:00","2014-01-01T08:00:00+00:00","2014-02-01T08:00:00+00:00","2014-03-01T08:00:00+00:00","2014-04-01T07:00:00+00:00","2014-05-01T07:00:00+00:00","2014-06-01T07:00:00+00:00","2014-07-01T07:00:00+00:00","2014-08-01T07:00:00+00:00","2014-09-01T07:00:00+00:00","2014-10-01T07:00:00+00:00","2014-11-01T07:00:00+00:00","2014-12-01T08:00:00+00:00","2015-01-01T08:00:00+00:00","2015-02-01T08:00:00+00:00","2015-03-01T08:00:00+00:00","2015-04-01T07:00:00+00:00","2015-05-01T07:00:00+00:00","2015-06-01T07:00:00+00:00","2015-07-01T07:00:00+00:00","2015-08-01T07:00:00+00:00","2015-09-01T07:00:00+00:00","2015-10-01T07:00:00+00:00","2015-11-01T07:00:00+00:00","2015-12-01T08:00:00+00:00","2016-01-01T08:00:00+00:00","2016-02-01T08:00:00+00:00","2016-03-01T08:00:00+00:00","2016-04-01T07:00:00+00:00","2016-05-01T07:00:00+00:00","2016-06-01T07:00:00+00:00","2016-07-01T07:00:00+00:00","2016-08-01T07:00:00+00:00","2016-09-01T07:00:00+00:00","2016-10-01T07:00:00+00:00","2016-11-01T07:00:00+00:00","2016-12-01T08:00:00+00:00","2017-01-01T08:00:00+00:00","2017-02-01T08:00:00+00:00","2017-03-01T08:00:00+00:00","2017-04-01T07:00:00+00:00","2017-05-01T07:00:00+00:00","2017-06-01T07:00:00+00:00","2017-07-01T07:00:00+00:00","2017-08-01T07:00:00+00:00","2017-09-01T07:00:00+00:00","2017-10-01T07:00:00+00:00","2017-11-01T07:00:00+00:00","2017-12-01T08:00:00+00:00","2018-01-01T08:00:00+00:00","2018-02-01T08:00:00+00:00","2018-03-01T08:00:00+00:00","2018-04-01T07:00:00+00:00","2018-05-01T07:00:00+00:00","2018-06-01T07:00:00+00:00","2018-07-01T07:00:00+00:00","2018-08-01T07:00:00+00:00","2018-09-01T07:00:00+00:00","2018-10-01T07:00:00+00:00","2018-11-01T07:00:00+00:00","2018-12-01T08:00:00+00:00","2019-01-01T08:00:00+00:00","2019-02-01T08:00:00+00:00","2019-03-01T08:00:00+00:00","2019-04-01T07:00:00+00:00","2019-05-01T07:00:00+00:00","2019-06-01T07:00:00+00:00","2019-07-01T07:00:00+00:00","2019-08-01T07:00:00+00:00","2019-09-01T07:00:00+00:00","2019-10-01T07:00:00+00:00","2019-11-01T07:00:00+00:00","2019-12-01T08:00:00+00:00","2020-01-01T08:00:00+00:00"],"xaxis":"x","y":[5,16,30,26,27,30,26,27,31,28,31,30,31,31,30,21,30,31,31,28,31,30,31,30,31,31,30,31,30,31,19,19,30,30,31,30,30,31,30,30,18,31,26,5,1,0,0,17,31,31,30,31,30,31,26,3,1,0,4,29,31,30,30,31,30,31,30,26,13,30,31,30,31,31,23,31,20,23,25,28,31,26,9,0,13,30,29,19,29,30,31,15,31,30,31,30,25,31,30,31,30,31,15],"yaxis":"y"} ...

# %% [markdown]
# ## Well map
#
# When asset have location data, like the well of the current dataset, it's easy with Plotly to get a map like below.

# %%
import plotly.express as px

fig = px.scatter_mapbox(
    wells_meta,
    lat="Latitude",
    lon="Longitude",
    text="API_No",
    zoom=9.0,
    title="Well locations",
)
fig.update_traces(marker=dict(size=10, color="green"))
fig.update_layout(mapbox_style="open-street-map")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="e372d396-8142-456c-875d-40e091bbc491" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e372d396-8142-456c-875d-40e091bbc491")) {                    Plotly.newPlot(                        "e372d396-8142-456c-875d-40e091bbc491",                        [{"hovertemplate":"API_No=%{text}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>","lat":[48.04714687,48.07915133,48.02831343,48.05743788,48.08269042,48.08269808,48.0823284,48.08032359,48.08291359,48.08274272,48.08273047,48.0250638,48.02494437,48.02494443,48.08261179,48.07967216,48.10943423,48.10943935,48.10944447,48.10944959,48.10945471,48.10945983,48.10949327,48.10949885,48.10950442,48.10951,48.10953478,48.10954035,48.10954593,48.10955151,48.07485888,48.07513115,48.07523533,48.07534225,48.07544917,48.08262327,48.03171771,48.03180818,48.04416229,48.05586616,48.04226612,48.04129824,48.04244703,48.04120778,48.055775700000005,48.05564139,48.05555093,48.06179631,48.06170585,48.06152493,48.06134401,48.06143447,48.06125355,48.06908749,48.06899703,48.06872565,48.06863519,48.04102686,48.07454242,48.07445196,48.0743615,48.04873617,48.04891708,48.07898685,48.07906909,48.02615372,48.02633464,48.07923356,48.0358351,48.03592554,48.07463288,48.03565421],"legendgroup":"","lon":[-103.60310009999999,-103.6027222,-103.602885,-103.6023545,-103.611486,-103.6118955,-103.6357292,-103.65549770000001,-103.6226339,-103.6142827,-103.6136276,-103.6221354,-103.6050634,-103.60516559999999,-103.6072806,-103.60254470000001,-103.72749379999999,-103.7276782,-103.7278625,-103.7280468,-103.7282311,-103.7284155,-103.7296033,-103.7297876,-103.729972,-103.73015629999999,-103.7309755,-103.7311598,-103.7313441,-103.73152840000002,-103.6701705,-103.66996740000002,-103.6698738,-103.6697803,-103.66968670000001,-103.6078948,-103.60308470000001,-103.60308559999999,-103.6026696,-103.6049027,-103.6031583,-103.6030142,-103.6031546,-103.60301609999999,-103.60490329999999,-103.60490420000001,-103.6049048,-103.6025215,-103.60252220000001,-103.60252340000001,-103.6025246,-103.602524,-103.6025252,-103.6028693,-103.6028681,-103.60286459999999,-103.6028634,-103.6030197,-103.6029364,-103.6029352,-103.60293399999999,-103.6029041,-103.60290040000001,-103.6028347,-103.60278249999999,-103.602783,-103.6027847,-103.60266999999999,-103.60311109999999,-103.6030997,-103.6029375,-103.60312990000001],"marker":{"color":"green","size":10},"mode":"markers+text","name":"","showlegend":false,"subplot":"mapbox","text":["33-053-03413-00-00","33-053-03426-00-00","33-053-03433-00-00","33-053-03472-00-00","33-053-03608-00-00","33-053-03609-00-00","33-053-03703-00-00","33-053-03846-00-00","33-053-03911-00-00","33-053-03936-00-00","33-053-03937-00-00","33-053-03943-00-00","33-053-03944-00-00","33-053-04069-00-00","33-053-04071-00-00","33-053-04211-00-00","33-105-02719-00-00","33-105-02720-00-00","33-105-02721-00-00","33-105-02722-00-00","33-105-02723-00-00","33-105-02724-00-00","33-105-02725-00-00","33-105-02726-00-00","33-105-02727-00-00","33-105-02728-00-00","33-105-02729-00-00","33-105-02730-00-00","33-105-02731-00-00","33-105-02732-00-00","33-053-04852-00-00","33-053-04853-00-00","33-053-04854-00-00","33-053-04855-00-00","33-053-04856-00-00","33-053-04981-00-00","33-053-05845-00-00","33-053-05849-00-00","33-053-05906-00-00","33-053-05924-00-00","33-053-05943-00-00","33-053-05954-00-00","33-053-05995-00-00","33-053-05998-00-00","33-053-06010-00-00","33-053-06011-00-00","33-053-06012-00-00","33-053-06018-00-00","33-053-06019-00-00","33-053-06021-00-00","33-053-06022-00-00","33-053-06023-00-00","33-053-06024-00-00","33-053-06025-00-00","33-053-06026-00-00","33-053-06028-00-00","33-053-06029-00-00","33-053-06051-00-00","33-053-06055-00-00","33-053-06056-00-00"," ...

# %% [markdown]
# <details>
#     <summary><b>NOTE: the graph above doesn't show correctly on Github, click here to see a screenshot</b></summary>
# <a><img alt="Well map" src="https://academichub.blob.core.windows.net/images/usc-well-data-location-map.png"></a>
# </details>
